# %% [markdown]
# <a href="https://colab.research.google.com/github/TetianaMar-888/Python_for_ds_tasks/blob/main/Marinoshenko_Tetiana_HW2_%D0%A1%D0%BF%D0%B8%D1%81%D0%BA%D0%B8_%D1%82%D0%B0_%D1%81%D0%BB%D0%BE%D0%B2%D0%BD%D0%B8%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Списки - базові операції**
#
# Створіть список температур за тиждень (у градусах Цельсія) з назвою
# `temperatures` і значеннями [22, 25, 19, 23, 26, 20, 21, 22].
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть перший елемент
# - Виведіть останній елемент
# - Додайте температуру 24
# - Видаліть температуру 19
# - Виведіть довжину списку
# - Обчисліть суму всіх температур
# - Знайдіть максимальну температуру

# %%
#Створюємо список
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]
print(f"Температура: {temperatures[0:]}°C")
# Out:
# Температура: [22, 25, 19, 23, 26, 20, 21, 22]°C

# %%
#Виводимо перший елемент
print(f"{temperatures[0]}°C")

# Виводимо останній елемент
print(f"{temperatures[-1]}°C")
# Out:
# 22°C
# 22°C

# %%
# Додамо температуру 24
temperatures.append(24)
temperatures
# Out:
# [22, 25, 19, 23, 26, 20, 21, 22, 24]

# %%
# Видалимо температуру 19
temperatures.remove(19)
temperatures
# Out:
# [22, 25, 23, 26, 20, 21, 22, 24]

# %%
# Виводимо довжину списку
print(len(temperatures))
# Out:
# 8

# %%
# Обчислюємо суму всих температур
print(f"{sum(temperatures)}°C")
# Out:
# 183°C

# %%
# Максимальна температура
print(f"{max(temperatures)}°C")
# Out:
# 26°C

# %% [markdown]
# **2. Словники - базові операції**
#
# Створіть словник про себе, який містить ключі `name`, `age`, `city` і значення, які відповідають вашему імені, віку і місту (можна вставити будь-які значення, не обовʼязково свої).
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть значення ключа "name"
# - Змініть значення ключа "age" на 21
# - Додайте новий ключ "hobby" зі значенням "programming"
# - Виведіть всі ключі
# - Виведіть всі значення

# %%
# Створюємо словник
profile = {
    "name": "Tetiana",
    "age": "34",
    "city": "Pisa"
}

# %%
profile
# Out:
# {'name': 'Tetiana', 'age': '34', 'city': 'Pisa'}

# %%
# Виводимо значення ключа "name"
print(profile["name"])
# Out:
# Tetiana

# %%
# Змінюємо значення ключа "age" на 21
profile["age"] = 21
print(profile["age"])
# Out:
# 21

# %%
# Додаємо новий ключ "hobby" зі значенням "programming"
profile["hobby"] = "Programming"
print(profile["hobby"])
# Out:
# Programming

# %%
# Виводимо всі ключі
print(profile.keys())

# Виводимо всі значення
print(profile.values())
# Out:
# dict_keys(['name', 'age', 'city', 'hobby'])
# dict_values(['Tetiana', 21, 'Pisa', 'Programming'])
