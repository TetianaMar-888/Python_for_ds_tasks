# %% [markdown]
# <a href="https://colab.research.google.com/github/TetianaMar-888/Python_for_ds_tasks/blob/main/Marinoshenko_Tetiana_HW3_%D0%A3%D0%BC%D0%BE%D0%B2%D0%BD%D1%96_%D0%BA%D0%BE%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%86%D1%96%D1%97_(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Основи роботи з умовними конструкціями (if-elif-else)**
#
# Створіть змінну `cooking_time = 5` (час варіння яєць у хвилинах)
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Яйце рідке" якщо cooking_time < 4
# - "Яйце всмятку" якщо 4 <= cooking_time < 7
# - "Яйце вкруту" якщо 7 <= cooking_time < 10
# - "Яйце переварене" якщо cooking_time >= 10

# %%
cooking_time = 5

# %%
# Готовність яйця
cooking_time = 5
if cooking_time < 4:
  print("Яйце рідке")
elif cooking_time < 7:
  print("Яйце в смятку")
elif cooking_time < 10:
  print("Яйце в круту")
else:
  print("Яйце переварене")
# Out:
# Яйце в смятку

# %% [markdown]
# ---
#
# **2. Перевірка оцінки**
#
# Створіть змінну `grade = 72`
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Відмінно" якщо grade >= 90
# - "Добре" якщо 75 <= grade < 90
# - "Задовільно" якщо 60 <= grade < 75
# - "Незадовільно" якщо grade < 60

# %%
# Перевірка оцінкизкщвгсе
grade = 72
if grade >= 90:
  print("Відмінно")
elif grade >= 75:
  print("Добре")
elif grade >= 60:
  print("Задовільно")
else:
  print("Незадовільно")
# Out:
# Задовільно

# %% [markdown]
# ---
#
# **3. Перевірка на наявність**
#
# Створіть список продуктів в холодильнику зі значеннями ["молоко", "яйця", "масло", "сир"] і запишіть його в змінну.
#
#
# Напишіть код, який перевіряє (кожен пункт оцінюється в 0.5 бала):
# - Чи є "яйця" в списку (виведіть "Яйця є в холодильнику" або "Яєць немає")
# - Чи є "хліб" в списку

# %%
products = ["молоко", "яйця", "масло", "сир"]
find_prod = "яйця"
if find_prod in products:
  print(f"{find_prod} є в холодильнику")
else:
  print(f"{find_prod} немає")
# Out:
# яйця є в холодильнику

# %%
products = ["молоко", "яйця", "масло", "сир"]
find_prod = "хліб"
if find_prod in products:
  print(f"{find_prod} є в холодильнику")
else:
  print(f"{find_prod} немає")
# Out:
# хліб немає
